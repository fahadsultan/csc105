# %% [markdown]
# # Q. Convert time from 12-hour format to 24-hour format
#
# Given three _**integers**_ `clock_12hrs_hrs`, `clock_12hrs_mins` and `pm` representing hours, minutes and AM/PM respectively in 12-hour time format, set integers `clock_24hrs_hrs` and `clock_24hrs_mins` to corresponding hours and minutes in 24-hour format time.
#
# `pm` $=0$ indicates input time is AM and `pm` $= 1$ means otherwise.
#
# Feel free to introduce new variables, as needed.
#
# _Constraints on input:_ \
# $0 \leq $ `pm` $ \leq 1$ \
# $1 \leq $ `clock_12hrs_hrs` $\leq 12$ \
# $ 0 \leq $ `clock_12hrs_mins` $ \lt 60 $
#
# <hr/>
#
# **Example 1** \
# _Input : 7:30 PM_ \
# `clock_12hrs_hrs  = 7` \
# `clock_12hrs_mins = 30` \
# `pm = 1`
#
# _Outputs: 19:30_ \
# `clock_24hrs_hrs = 19`\
# `clock_24hrs_mins = 30`
#
# **Example 2** \
# _Input : 3:14 AM_ \
# `clock_12hrs_hrs  = 3` \
# `clock_12hrs_mins = 14`\
# `pm = 0`
#
# _Outputs: 3:14_ \
# `clock_24hrs_hrs = 3` \
# `clock_24hrs_mins = 14`
#
# **Example 3** \
# _Input : 12:00 PM_ \
# `clock_12hrs_hrs  = 12` \
# `clock_12hrs_mins = 0`\
# `pm = 1`
#
# _Outputs: 12:00_ \
# `clock_24hrs_hrs = 12` \
# `clock_24hrs_mins = 0`
#
# **Example 4** \
# _Input : 12:00 AM_ \
# `clock_12hrs_hrs  = 12` \
# `clock_12hrs_mins = 0`\
# `pm = 0`
#
# _Outputs: 0:00_ \
# `clock_24hrs_hrs = 0` \
# `clock_24hrs_mins = 0`
#
# <hr/>
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-1wig{font-weight:bold;text-align:left;vertical-align:top}
# .tg .tg-0lax{text-align:left;vertical-align:top}
# .tg .tg-0g60{background-color:#dae8fc;font-weight:bold;text-align:center;vertical-align:top}
# .tg .tg-5qfb{background-color:#ffce93;font-weight:bold;text-align:center;vertical-align:top}
# .tg .tg-mfwa{background-color:#dae8fc;font-family:"Courier New", Courier, monospace !important;font-weight:bold;text-align:center;
#   vertical-align:top}
# .tg .tg-rq5l{background-color:#ffce93;font-family:"Courier New", Courier, monospace !important;font-weight:bold;text-align:center;
#   vertical-align:top}
# .tg .tg-d53b{background-color:#dae8fc;text-align:center;vertical-align:top}
# .tg .tg-ifcm{background-color:#ffce93;text-align:center;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-0lax"></th>
#     <th class="tg-0lax"></th>
#     <th class="tg-0g60" colspan="3">Inputs</th>
#     <th class="tg-0lax"></th>
#     <th class="tg-5qfb" colspan="2">Outputs</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-1wig">Example</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-mfwa">clock_12hrs_hrs</td>
#     <td class="tg-mfwa">clock_12hrs_mins</td>
#     <td class="tg-mfwa">pm</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-rq5l">clock_24hrs_hrs</td>
#     <td class="tg-rq5l">clock_24hrs_mins</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">1</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-d53b">7</td>
#     <td class="tg-d53b">30</td>
#     <td class="tg-d53b">1</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-ifcm">19</td>
#     <td class="tg-ifcm">30</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">2</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-d53b">3</td>
#     <td class="tg-d53b">14</td>
#     <td class="tg-d53b">0</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-ifcm">3</td>
#     <td class="tg-ifcm">14</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">3</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-d53b">12</td>
#     <td class="tg-d53b">0</td>
#     <td class="tg-d53b">1</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-ifcm">12</td>
#     <td class="tg-ifcm">0</td>
#   </tr>
#   <tr>
#     <td class="tg-0lax">4</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-d53b">12</td>
#     <td class="tg-d53b">0</td>
#     <td class="tg-d53b">0</td>
#     <td class="tg-0lax"></td>
#     <td class="tg-ifcm">0</td>
#     <td class="tg-ifcm">0</td>
#   </tr>
# </tbody>
# </table>
#
#
# <hr/>
#
# <span style="color:red"><i><b>Make sure you test your code for inputs other than the ones provided above</b><i/></span>

# %%
print("\n\nWelcome to the time format conversion program!\n\
       \r----------------------------------------------\n\
       \rUsing this program, you can convert any time from 12-hr format to 24-hr format time\n\n")

clock_12hrs_hrs  = int(input("How many hours in the 12-hr format time?   \n"))
clock_12hrs_mins = int(input("How many minutes in the 12-hr format time? \n"))
pm               = int(input("Is it PM? Enter 1 for yes and 0 for no (AM)\n"))


#Write your code here to compute time in 24-hr format 

clock_24hrs_hrs  = 10

clock_24hrs_mins = 10


print("\n\nThe given time in 12-hr format, when converted to 24-hr format, becomes:\n",\
      clock_24hrs_hrs,\
      ":",\
       clock_24hrs_mins)
